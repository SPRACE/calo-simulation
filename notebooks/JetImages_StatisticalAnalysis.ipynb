# %%
from charts import *

# %%
data_eminus_50   = sttstcs('./eminus_Ele-Eta0-PhiPiOver2-Energy50.json'   )
data_eminus_100  = sttstcs('./eminus_Ele-Eta0-PhiPiOver2-Energy100.json'  )

data_piminus_50  = sttstcs('./piminus_Pion-Eta0-PhiPiOver2-Energy50.json' )
data_piminus_100 = sttstcs('./piminus_Pion-Eta0-PhiPiOver2-Energy100.json')

data_gamma_50    = sttstcs('./gamma-Photon-Eta0-PhiPiOver2-Energy50.json' )
data_gamma_100   = sttstcs('./gamma-Photon-Eta0-PhiPiOver2-Energy100.json')
# Out:
# /home/jfialho/miniconda3/envs/jupyter/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3194: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /home/jfialho/miniconda3/envs/jupyter/lib/python3.6/site-packages/numpy/core/_methods.py:127: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
title_phi = "<b>PHI Projection</b><br>"
title_eta = "<b>ETA Projection</b><br>"

plot_lines(phi_projection(data_eminus_50)  , title_phi + "data_eminus_50"  , "Energy [GeV]", "PHI", "x_log")
plot_lines(eta_projection(data_eminus_100) , title_eta + "data_eminus_100" , "Energy [GeV]", "ETA", "x_log")
# Out:
# <div id="591bf86b-47ec-45d0-b72d-62dde0455a49" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("591bf86b-47ec-45d0-b72d-62dde0455a49", [{"type": "scatter", "x": [8.90287291319874e-05, 9.458757068931711e-05, 6.613690821423168e-05, 0.00010038048904484994, 8.131674682893025e-05, 8.075436410721128e-05, 8.381694480844217e-05, 7.102416225216612e-05, 0.00011268439959594689, 8.982908197276915e-05, 9.58532495192324e-05, 0.00011162509794727387, 9.435780050813467e-05, 9.306538839950973e-05, 0.00010515772952915677, 9.559601071846309e-05, 0.00010555630706508913, 8.621761749692534e-05, 0.0001173014509802695, 0.00015225949074619712, 0.00013296650831013393, 9.043263923744603e-05, 8.506162516721364e-05, 0.0001289538400884773, 0.00010574902830485334, 0.00012661919224449497, 0.00011153675832948196, 9.530269192606967e-
# ...

# %%
plot_lines(phi_projection(data_piminus_50) , title_phi + "data_piminus_50" , "Energy [GeV]", "PHI", "x_log")
plot_lines(eta_projection(data_piminus_100), title_eta + "data_piminus_100", "Energy [GeV]", "ETA", "x_log")
# Out:
# <div id="cf3a3a63-8fcf-4379-983a-656ece228b16" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cf3a3a63-8fcf-4379-983a-656ece228b16", [{"type": "scatter", "x": [0.00018383402772070284, 0.0001869995878508242, 0.00018750222637698585, 0.00019498293202444412, 0.00022202217111480968, 0.00019590406541665476, 0.0001851736961325185, 0.00018565869889915473, 0.00025883895293429886, 0.00024020717663859745, 0.00015252154793466316, 0.00021419380639808736, 0.0001985224165835956, 0.00018593988329587908, 0.00020135548108250916, 0.00019675695076743806, 0.00020229574858775704, 0.00022384974400536917, 0.00023392812437660136, 0.00026743492766863005, 0.0002660249389903421, 0.00021056287209603942, 0.00026621126231176137, 0.00029034869907315733, 0.0002478044346247269, 0.0002413129173726478, 0.0002159266111691971, 0.00023
# ...

# %%
plot_lines(phi_projection(data_gamma_50)   , title_phi + "data_gamma_50"   , "Energy [GeV]", "PHI", "x_log")
plot_lines(eta_projection(data_gamma_100)  , title_eta + "data_gamma_100"  , "Energy [GeV]", "ETA", "x_log")
# Out:
# <div id="29d8d9f6-1826-4bb7-8e2f-59c7ac1cdb63" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("29d8d9f6-1826-4bb7-8e2f-59c7ac1cdb63", [{"type": "scatter", "x": [2.8274294734522728e-05, 2.3849224366726744e-05, 2.3254156302782808e-05, 2.6181245711988817e-05, 2.2996517692482735e-05, 1.4646192279298317e-05, 3.3003462160069745e-05, 2.256384904041238e-05, 1.5957396844318142e-05, 2.2152468557926543e-05, 1.9278812660975495e-05, 8.105290237548843e-06, 1.9013610792222476e-05, 1.2033909895084147e-05, 1.9763867422026443e-05, 3.088774781551906e-05, 2.480646849323073e-05, 3.737419533737103e-05, 2.0158158340133708e-05, 2.116845246106417e-05, 2.721347526356485e-05, 2.1044321400011013e-05, 2.6342554920007273e-05, 2.7960292436652134e-05, 1.9582458608296087e-05, 2.766962641246768e-05, 1.942866733454895e-05, 2.8419992
# ...
